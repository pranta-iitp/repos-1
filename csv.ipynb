# %%
import pandas as pd

# %%
df = pd.read_csv("machine-readable-business-employment-data-sep-2024-quarter.csv",header=0,
                 names=["Series_reference","Period","Data_value","Suppressed(Y/N)","STATUS","Type of Units",
                        "Magnitude","Subject","Group","Type of job","Type of business","Actual(Y/N)","Series_4","Series_5"],index_col="Series_reference")

# %%
df
# Out:
#                    Period  Data_value Suppressed(Y/N) STATUS Type of Units  \
# Series_reference
# BDCQ.SEA1AA       2011.06     80078.0             NaN      F        Number
# BDCQ.SEA1AA       2011.09     78324.0             NaN      F        Number
# BDCQ.SEA1AA       2011.12     85850.0             NaN      F        Number
# BDCQ.SEA1AA       2012.03     90743.0             NaN      F        Number
# BDCQ.SEA1AA       2012.06     81780.0             NaN      F        Number
# ...                   ...         ...             ...    ...           ...
# BDCQ.SEE3999A     2017.06         NaN               Y      C        Number
# BDCQ.SEE3999A     2017.09         NaN               Y      C        Number
# BDCQ.SEE3999A     2017.12         NaN               Y      C        Number
# BDCQ.SEE3999A     2018.03         NaN               Y      C        Number
# BDCQ.SEE3999A     2018.06         NaN               Y      C        Number
#
# ...
