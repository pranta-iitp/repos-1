# %%
import pandas as pd

# %%
df = pd.read_csv("machine-readable-business-employment-data-sep-2024-quarter.csv",header=0,
                 names=["Series_reference","Period","Data_value","Suppressed(Y/N)","STATUS","Type of Units",
                        "Magnitude","Subject","Group","Type of job","Type of business","Actual(Y/N)","Series_4","Series_5"],index_col="Series_reference")

# %%
df
# Out:
#       Series_reference   Period  Data_value Suppressed(Y/N) STATUS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0             NaN      F
# 1          BDCQ.SEA1AA  2011.09     78324.0             NaN      F
# 2          BDCQ.SEA1AA  2011.12     85850.0             NaN      F
# 3          BDCQ.SEA1AA  2012.03     90743.0             NaN      F
# 4          BDCQ.SEA1AA  2012.06     81780.0             NaN      F
# ...                ...      ...         ...             ...    ...
# 23732    BDCQ.SEE3999A  2017.06         NaN               Y      C
# 23733    BDCQ.SEE3999A  2017.09         NaN               Y      C
# 23734    BDCQ.SEE3999A  2017.12         NaN               Y      C
# 23735    BDCQ.SEE3999A  2018.03         NaN               Y      C
# 23736    BDCQ.SEE3999A  2018.06         NaN               Y      C
#
#       Type of Units  Magnitude                         Subject  \
# 0            Number          0  Business Data Collection - BDC
# 1            Number          0  Business Data Collection - BDC
# 2            Number          0  Business Data Collection - BDC
# 3            Number          0  Business Data Collection - BDC
# 4            Number          0  Business Data Collection - BDC
# ...             ...        ...                             ...
# 23732        Number          0  Business Data Collection - BDC
# 23733        Number          0  Business Data Collection - BDC
# 23734        Number          0  Business Data Collection - BDC
# 23735        Number          0  Business Data Collection - BDC
# 23736        Number          0  Business Data Collection - BDC
#
#                                               Group  \
# 0                   Industry by employment variable
# 1                   Industry by employment variable
# 2                   Industry by employment variable
# 3                   Industry by employment variable
# 4                   Industry by employment variable
# ...                                             ...
# 23732  Territorial authority by employment variable
# 23733  Territorial authority by employment variable
# 23734  Territorial authority by employment variable
# 23735  Territorial authority by employment variable
# 23736  Territorial authority by employment variable
#
#                                   Type of job  \
# 0                                 Filled jobs
# 1                                 Filled jobs
# 2                                 Filled jobs
# 3                                 Filled jobs
# 4                                 Filled jobs
# ...                                       ...
# 23732  Filled jobs (workplace location based)
# 23733  Filled jobs (workplace location based)
# 23734  Filled jobs (workplace location based)
# 23735  Filled jobs (workplace location based)
# 23736  Filled jobs (workplace location based)
#
#                          Type of business Actual(Y/N)  Series_4  Series_5
# 0       Agriculture, Forestry and Fishing      Actual       NaN       NaN
# 1       Agriculture, Forestry and Fishing      Actual       NaN       NaN
# 2       Agriculture, Forestry and Fishing      Actual       NaN       NaN
# 3       Agriculture, Forestry and Fishing      Actual       NaN       NaN
# 4       Agriculture, Forestry and Fishing      Actual       NaN       NaN
# ...                                   ...         ...       ...       ...
# 23732  Area Outside Territorial Authority      Actual       NaN       NaN
# 23733  Area Outside Territorial Authority      Actual       NaN       NaN
# 23734  Area Outside Territorial Authority      Actual       NaN       NaN
# 23735  Area Outside Territorial Authority      Actual       NaN       NaN
# 23736  Area Outside Territorial Authority      Actual       NaN       NaN
#
# [23737 rows x 14 columns]
